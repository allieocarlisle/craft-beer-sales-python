# %% [markdown]
# # EDA + Cleaning

# %% [markdown]
# ## Table of Contents:
#
# 1. Import Libraries + Data
# 2. Explore the Data Sets
# 3. Data Wrangling and Consistency Checks
#     - Renaming Columns
#     - Mixed Types Check
#     - Missing Values
#     - Duplicate Values
# 4. Merge Data Sets
# 5. Export Data Set

# %% [markdown]
# ## 01. Import Libraries + Data

# %%
# importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# import data path
path = r'/Users/alliecarlisle/Desktop/CareerFoundry_Data_Analytics/Craft_Beer_Sales_Analysis'

# %%
path
# Out:
# '/Users/alliecarlisle/Desktop/CareerFoundry_Data_Analytics/Craft_Beer_Sales_Analysis'

# %%
#import transactions.csv
df_trans = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'transactions.csv'), index_col = False)

# %%
# check head to ensure it's the right data set
df_trans.head(4)
# Out:
#   full_date  year month  day_of_month day_of_week   time  Product_code  \
# 0  1/1/2020  2020   Jan             1   Wednesday  23:00           144
# 1  1/1/2020  2020   Jan             1   Wednesday  23:00           209
# 2  1/1/2020  2020   Jan             1   Wednesday  23:00           213
# 3  1/1/2020  2020   Jan             1   Wednesday  23:00           217
#
#    Amount  Sale_amount  Discount_amount  Profit  Percentage_markup  \
# 0     1.0       280.00              NaN  155.00             124.00
# 1     2.0       545.73           294.27   75.73              16.11
# 2     2.0      1265.05            34.95  653.05             106.71
# 3     1.0       630.00            70.00  220.50              53.85
#
#    Discount_percentage
# 0                  NaN
# 1                35.03
# 2                 2.69
# 3                10.00

# %%
# check shape to ensure it's the right data set
df_trans.shape
# Out:
# (50084, 13)

# %%
# import product_range.csv
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'product_range.csv'), index_col = False)

# %%
# check head to ensure it's the right data set
df_prods.head(4)
# Out:
#    Product_code Vendor_code                                             Name  \
# 0          5028         NaN                         1 Symbiotica Apple 0.375
# 1          4846         NaN  1 Symbiotica Hard Kombucha Renegade Aronia 0.33
# 2          1340         NaN                   1000 IBU Imperial IPA Barrel l
# 3          4372         NaN                              18th Street Brewery
#
#    Retail_price Base_unit Country_of_Origin   Size  ABV
# 0         300.0    Pieces            Russia  0.375  4.5
# 1         200.0    Pieces            Russia  0.330  3.0
# 2         960.0    Liters               NaN  1.000  9.6
# 3           NaN       NaN               USA    NaN  NaN

# %%
# check shap to ensure it's the right data set
df_prods.shape
# Out:
# (5314, 8)

# %% [markdown]
# ## 02. Explore Data Sets

# %%
df_trans.tail()
# Out:
#        full_date  year month  day_of_month day_of_week   time  Product_code  \
# 50079  9/18/2022  2022   Sep            18      Sunday  15:00          5316
# 50080  9/18/2022  2022   Sep            18      Sunday  15:00          5317
# 50081  9/18/2022  2022   Sep            18      Sunday  15:00          5318
# 50082  9/18/2022  2022   Sep            18      Sunday  15:00          5321
# 50083  9/18/2022  2022   Sep            18      Sunday  15:00          5322
#
#        Amount  Sale_amount  Discount_amount   Profit  Percentage_markup  \
# 50079     6.0      1875.95           104.05  1095.95             140.51
# 50080     2.0       555.95           104.05   315.95             131.65
# 50081     2.0       572.50            87.50   312.50             120.19
# 50082     1.0       300.00              NaN   180.00             150.00
# 50083     2.0       600.00              NaN   340.00             130.77
#
#        Discount_percentage
# 50079                 5.26
# 50080                15.77
# 50081                13.26
# 50082                  NaN
# 50083                  NaN

# %%
df_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50084 entries, 0 to 50083
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   full_date            50084 non-null  object
#  1   year                 50084 non-null  int64
#  2   month                50084 non-null  object
#  3   day_of_month         50084 non-null  int64
#  4   day_of_week          50084 non-null  object
#  5   time                 50084 non-null  object
#  6   Product_code         50084 non-null  int64
#  7   Amount               50084 non-null  float64
#  8   Sale_amount          50033 non-null  float64
#  9   Discount_amount      39882 non-null  float64
#  10  Profit               50070 non-null  float64
#  11  Percentage_markup    48145 non-null  float64
#  12  Discount_percentage  39882 non-null  float64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 5.0+ MB

# %%
df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5314 entries, 0 to 5313
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Product_code       5314 non-null   int64
#  1   Vendor_code        4288 non-null   object
#  2   Name               5314 non-null   object
#  3   Retail_price       4878 non-null   float64
#  4   Base_unit          4910 non-null   object
#  5   Country_of_Origin  4205 non-null   object
#  6   Size               4626 non-null   float64
#  7   ABV                4622 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 332.2+ KB

# %%
df_prods.tail()
# Out:
#       Product_code Vendor_code  \
# 5309           868         NaN
# 5310          1861         NaN
# 5311          4724         NaN
# 5312           822     Bakunin
# 5313          1682         NaN
#
#                                                    Name  Retail_price  \
# 5309                                   Spagetti Vestern         880.0
# 5310                Stoun Imperial Rashn Stout Barrel l        1200.0
# 5311                  Semjuel Adams Boston Lager Barrel         720.0
# 5312                                Bakunin Urban Juice         600.0
# 5313  Hazeljuteli Shoktabulous Barrel l temnoe fil't...         880.0
#
#      Base_unit Country_of_Origin  Size   ABV
# 5309    Liters               NaN   1.0   8.7
# 5310    Liters               NaN   1.0  10.8
# 5311    Liters               NaN   1.0   4.8
# 5312    Liters            Russia   1.0   7.2
# 5313    Liters               NaN   1.0   5.7

# %%
df_trans.head(20)
# Out:
#    full_date  year month  day_of_month day_of_week   time  Product_code  \
# 0   1/1/2020  2020   Jan             1   Wednesday  23:00           144
# 1   1/1/2020  2020   Jan             1   Wednesday  23:00           209
# 2   1/1/2020  2020   Jan             1   Wednesday  23:00           213
# 3   1/1/2020  2020   Jan             1   Wednesday  23:00           217
# 4   1/1/2020  2020   Jan             1   Wednesday  23:00           222
# 5   1/1/2020  2020   Jan             1   Wednesday  23:00           243
# 6   1/1/2020  2020   Jan             1   Wednesday  23:00           258
# 7   1/1/2020  2020   Jan             1   Wednesday  23:00           270
# 8   1/1/2020  2020   Jan             1   Wednesday  23:00           271
# 9   1/1/2020  2020   Jan             1   Wednesday  23:00           282
# 10  1/1/2020  2020   Jan             1   Wednesday  23:00           294
# 11  1/1/2020  2020   Jan             1   Wednesday  23:00           298
# 12  1/1/2020  2020   Jan             1   Wednesday  23:00           386
# 13  1/1/2020  2020   Jan             1   Wednesday  23:00           457
# 14  1/1/2020  2020   Jan             1   Wednesday  23:00           566
# 15  1/1/2020  2020   Jan             1   Wednesday  23:00           581
# 16  1/1/2020  2020   Jan             1   Wednesday  23:00           615
# 17  1/1/2020  2020   Jan             1   Wednesday  23:00           646
# 18  1/1/2020  2020   Jan             1   Wednesday  23:00           688
# 19  1/1/2020  2020   Jan             1   Wednesday  23:00           706
#
#     Amount  Sale_amount  Discount_amount  Profit  Percentage_markup  \
# 0      1.0       280.00              NaN  155.00             124.00
# 1      2.0       545.73           294.27   75.73              16.11
# 2      2.0      1265.05            34.95  653.05             106.71
# 3      1.0       630.00            70.00  220.50              53.85
# 4      2.0      1104.75           195.25  393.75              55.38
# 5      1.0       292.36           157.64    1.36               0.47
# 6      1.0       559.55           240.45   93.55              20.08
# 7      2.0       497.82           242.18   35.82               7.75
# 8      1.0       324.84           175.16   53.84              19.87
# 9      1.0       423.00            47.00  252.00             147.37
# 10     1.0       324.84           175.16   25.84               8.64
# 11     1.0       180.00              NaN   90.32             100.71
# 12     1.0       370.00              NaN  165.00              80.49
# 13     1.0       230.00           100.00   51.00              28.49
# 14     3.0       549.42           110.58  211.35              62.52
# 15     5.0      2032.71           717.29  615.21              43.40
# 16     1.0       407.62            22.38  162.62              66.38
# 17     1.0       280.00              NaN  150.00             115.38
# 18     1.0       255.97            14.03  133.25             108.58
# 19     1.0       160.00              NaN   73.27              84.48
#
#     Discount_percentage
# 0                   NaN
# 1                 35.03
# 2                  2.69
# 3                 10.00
# 4                 15.02
# 5                 35.03
# 6                 30.06
# 7                 32.73
# 8                 35.03
# 9                 10.00
# 10                35.03
# 11                  NaN
# 12                  NaN
# 13                30.30
# 14                16.75
# 15                26.08
# 16                 5.20
# 17                  NaN
# 18                 5.20
# 19                  NaN

# %%
df_trans.tail(20)
# Out:
#        full_date  year month  day_of_month day_of_week   time  Product_code  \
# 50064  9/18/2022  2022   Sep            18      Sunday  15:00          5286
# 50065  9/18/2022  2022   Sep            18      Sunday  15:00          5288
# 50066  9/18/2022  2022   Sep            18      Sunday  15:00          5289
# 50067  9/18/2022  2022   Sep            18      Sunday  15:00          5290
# 50068  9/18/2022  2022   Sep            18      Sunday  15:00          5291
# 50069  9/18/2022  2022   Sep            18      Sunday  15:00          5293
# 50070  9/18/2022  2022   Sep            18      Sunday  15:00          5298
# 50071  9/18/2022  2022   Sep            18      Sunday  15:00          5299
# 50072  9/18/2022  2022   Sep            18      Sunday  15:00          5301
# 50073  9/18/2022  2022   Sep            18      Sunday  15:00          5302
# 50074  9/18/2022  2022   Sep            18      Sunday  15:00          5303
# 50075  9/18/2022  2022   Sep            18      Sunday  15:00          5305
# 50076  9/18/2022  2022   Sep            18      Sunday  15:00          5307
# 50077  9/18/2022  2022   Sep            18      Sunday  15:00          5309
# 50078  9/18/2022  2022   Sep            18      Sunday  15:00          5310
# 50079  9/18/2022  2022   Sep            18      Sunday  15:00          5316
# 50080  9/18/2022  2022   Sep            18      Sunday  15:00          5317
# 50081  9/18/2022  2022   Sep            18      Sunday  15:00          5318
# 50082  9/18/2022  2022   Sep            18      Sunday  15:00          5321
# 50083  9/18/2022  2022   Sep            18      Sunday  15:00          5322
#
#        Amount  Sale_amount  Discount_amount   Profit  Percentage_markup  \
# 50064   20.00      8320.00          2080.00  4320.00             108.00
# 50065    1.00       450.00              NaN   207.00              85.19
# 50066    2.00       480.00           320.00   102.00              26.98
# 50067    5.00      1750.83           449.17   570.83              48.38
# 50068   11.75     10297.12          1452.88  4010.87              63.80
# 50069    1.00       359.84            40.16   170.84              90.39
# 50070    1.00       431.81           288.19    32.81               8.22
# 50071    4.00      1296.55           383.45   420.55              48.01
# 50072    3.00      1500.00           240.00   555.00              58.73
# 50073    3.00       870.00           450.00   162.00              22.88
# 50074   12.00      3865.58          1534.42   925.58              31.48
# 50075    1.00       220.00              NaN   120.40             120.88
# 50076    1.00       190.00           160.00    20.00              11.76
# 50077    2.00       401.37           298.63    81.37              25.43
# 50078    4.00       914.21           285.79   374.21              69.30
# 50079    6.00      1875.95           104.05  1095.95             140.51
# 50080    2.00       555.95           104.05   315.95             131.65
# 50081    2.00       572.50            87.50   312.50             120.19
# 50082    1.00       300.00              NaN   180.00             150.00
# 50083    2.00       600.00              NaN   340.00             130.77
#
#        Discount_percentage
# 50064                20.00
# 50065                  NaN
# 50066                40.00
# 50067                20.42
# 50068                12.36
# 50069                10.04
# 50070                40.03
# 50071                22.82
# 50072                13.79
# 50073                34.09
# 50074                28.42
# 50075                  NaN
# 50076                45.71
# 50077                42.66
# 50078                23.82
# 50079                 5.26
# 50080                15.77
# 50081                13.26
# 50082                  NaN
# 50083                  NaN

# %%
df_prods.head(20)
# Out:
#     Product_code Vendor_code  \
# 0           5028         NaN
# 1           4846         NaN
# 2           1340         NaN
# 3           4372         NaN
# 4           4302         NaN
# 5           4304         NaN
# 6           4300         NaN
# 7           4775         NaN
# 8           4301         NaN
# 9           4303         NaN
# 10          4602         NaN
# 11          3488         NaN
# 12          4738         NaN
# 13          3041         NaN
# 14           170   3Fonteine
# 15          1176   3Fonteine
# 16           726   3Fonteine
# 17          1617   3Fonteine
# 18          4548   3Fonteine
# 19          1845   3Fonteine
#
#                                                  Name  Retail_price Base_unit  \
# 0                            1 Symbiotica Apple 0.375         300.0    Pieces
# 1     1 Symbiotica Hard Kombucha Renegade Aronia 0.33         200.0    Pieces
# 2                      1000 IBU Imperial IPA Barrel l         960.0    Liters
# 3                                 18th Street Brewery           NaN       NaN
# 4       18th Street Brewery Deal With The Devil 0.473         630.0    Pieces
# 5          18th Street Brewery Pins And Needles 0.473         630.0    Pieces
# 6        18th Street Brewery Rise Of The Angels 0.473         520.0    Pieces
# 7                   18th Street Brewery Rubicon 0.473         480.0    Pieces
# 8             18th Street Brewery Sex and Candy 0.473         480.0    Pieces
# 9               18th Street Brewery Under Crown 0.473         640.0    Pieces
# 10                                         Lambik Bar           NaN       NaN
# 11                                              Honey           NaN       NaN
# 12          2nd Shift Brewing Arancia e Ibisco Barrel         900.0    Liters
# 13                                                 2Y           NaN       NaN
# 14         3Fonteinen Doesjel 20/ lambic / 6% / 0.375         850.0    Pieces
# 15      3Fonteinen Intense Red Oude Kriek / 5% / 0.75        3300.0    Pieces
# 16                  3Fonteinen Oude Geuze / 6% / 0.75        1500.0    Pieces
# 17               3Fonteinen Oude Geuze 20/ 5% / 0.375         950.0    Pieces
# 18        3Fonteinen Oude Geuze 20Assemblage 59 0.375        1100.0    Pieces
# 19  3Fonteinen Oude Geuze 20assemlage 9/Oud Gez 2 ...        1600.0    Pieces
#
#    Country_of_Origin   Size  ABV
# 0             Russia  0.375  4.5
# 1             Russia  0.330  3.0
# 2                NaN  1.000  9.6
# 3                USA    NaN  NaN
# 4                USA  0.473  8.5
# 5                USA  0.473  8.5
# 6                USA  0.473  7.5
# 7                USA  0.473  7.0
# 8                USA  0.473  7.5
# 9                USA  0.473  8.8
# 10               NaN    NaN  NaN
# 11               NaN    NaN  NaN
# 12               USA  1.000  5.9
# 13               NaN    NaN  NaN
# 14           Belgium  0.375  6.0
# 15           Belgium  0.750  6.0
# 16           Belgium  0.750  6.0
# 17           Belgium  0.375  5.0
# 18           Belgium  0.375  6.6
# 19           Belgium  0.750  5.3

# %%
df_trans.tail(20)
# Out:
#        full_date  year month  day_of_month day_of_week   time  Product_code  \
# 50064  9/18/2022  2022   Sep            18      Sunday  15:00          5286
# 50065  9/18/2022  2022   Sep            18      Sunday  15:00          5288
# 50066  9/18/2022  2022   Sep            18      Sunday  15:00          5289
# 50067  9/18/2022  2022   Sep            18      Sunday  15:00          5290
# 50068  9/18/2022  2022   Sep            18      Sunday  15:00          5291
# 50069  9/18/2022  2022   Sep            18      Sunday  15:00          5293
# 50070  9/18/2022  2022   Sep            18      Sunday  15:00          5298
# 50071  9/18/2022  2022   Sep            18      Sunday  15:00          5299
# 50072  9/18/2022  2022   Sep            18      Sunday  15:00          5301
# 50073  9/18/2022  2022   Sep            18      Sunday  15:00          5302
# 50074  9/18/2022  2022   Sep            18      Sunday  15:00          5303
# 50075  9/18/2022  2022   Sep            18      Sunday  15:00          5305
# 50076  9/18/2022  2022   Sep            18      Sunday  15:00          5307
# 50077  9/18/2022  2022   Sep            18      Sunday  15:00          5309
# 50078  9/18/2022  2022   Sep            18      Sunday  15:00          5310
# 50079  9/18/2022  2022   Sep            18      Sunday  15:00          5316
# 50080  9/18/2022  2022   Sep            18      Sunday  15:00          5317
# 50081  9/18/2022  2022   Sep            18      Sunday  15:00          5318
# 50082  9/18/2022  2022   Sep            18      Sunday  15:00          5321
# 50083  9/18/2022  2022   Sep            18      Sunday  15:00          5322
#
#        Amount  Sale_amount  Discount_amount   Profit  Percentage_markup  \
# 50064   20.00      8320.00          2080.00  4320.00             108.00
# 50065    1.00       450.00              NaN   207.00              85.19
# 50066    2.00       480.00           320.00   102.00              26.98
# 50067    5.00      1750.83           449.17   570.83              48.38
# 50068   11.75     10297.12          1452.88  4010.87              63.80
# 50069    1.00       359.84            40.16   170.84              90.39
# 50070    1.00       431.81           288.19    32.81               8.22
# 50071    4.00      1296.55           383.45   420.55              48.01
# 50072    3.00      1500.00           240.00   555.00              58.73
# 50073    3.00       870.00           450.00   162.00              22.88
# 50074   12.00      3865.58          1534.42   925.58              31.48
# 50075    1.00       220.00              NaN   120.40             120.88
# 50076    1.00       190.00           160.00    20.00              11.76
# 50077    2.00       401.37           298.63    81.37              25.43
# 50078    4.00       914.21           285.79   374.21              69.30
# 50079    6.00      1875.95           104.05  1095.95             140.51
# 50080    2.00       555.95           104.05   315.95             131.65
# 50081    2.00       572.50            87.50   312.50             120.19
# 50082    1.00       300.00              NaN   180.00             150.00
# 50083    2.00       600.00              NaN   340.00             130.77
#
#        Discount_percentage
# 50064                20.00
# 50065                  NaN
# 50066                40.00
# 50067                20.42
# 50068                12.36
# 50069                10.04
# 50070                40.03
# 50071                22.82
# 50072                13.79
# 50073                34.09
# 50074                28.42
# 50075                  NaN
# 50076                45.71
# 50077                42.66
# 50078                23.82
# 50079                 5.26
# 50080                15.77
# 50081                13.26
# 50082                  NaN
# 50083                  NaN

# %%
df_trans.describe()
# Out:
#                year  day_of_month  Product_code        Amount   Sale_amount  \
# count  50084.000000  50084.000000  50084.000000  50084.000000  50033.000000
# mean    2020.616744     15.738180   2153.160031      3.553146   1429.786677
# std        0.730016      8.816442   1367.357705      5.485805   2419.585455
# min     2020.000000      1.000000     99.000000      0.033000      0.410000
# 25%     2020.000000      8.000000    899.000000      1.000000    330.000000
# 50%     2020.000000     16.000000   2098.000000      2.000000    630.000000
# 75%     2021.000000     23.000000   3059.000000      4.000000   1436.130000
# max     2022.000000     31.000000   5322.000000    248.000000  58184.070000
#
#        Discount_amount        Profit  Percentage_markup  Discount_percentage
# count     39882.000000  50070.000000       48145.000000         39882.000000
# mean        243.761323    705.901987         109.184511            17.251313
# std         405.902060   1352.628611        1182.538753            16.608075
# min           0.010000  -9300.630000        -100.000000             0.000000
# 25%          60.000000    143.070000          59.850000             7.930000
# 50%         121.760000    283.000000          84.210000            12.000000
# 75%         270.615000    687.015000         107.790000            20.210000
# max       20440.630000  33352.460000       79900.000000           100.000000

# %%
df_prods.describe()
# Out:
#        Product_code  Retail_price         Size          ABV
# count   5314.000000   4878.000000  4626.000000  4622.000000
# mean    2690.844750    637.839502     0.626917     7.074273
# std     1543.217814    504.895006     0.953290     2.457970
# min        2.000000      1.000000     0.150000     0.500000
# 25%     1357.250000    350.000000     0.330000     5.300000
# 50%     2690.500000    520.000000     0.500000     6.500000
# 75%     4027.750000    730.000000     1.000000     8.200000
# max     5358.000000   8484.850000    30.000000    21.000000

# %% [markdown]
# ### NOTES:
# - separate date and time in df_trans
# - check on NaNs in all but product_code and name in df_prods
# - check on NaNs in sale_amount, discount_amount, profit, percentage_markup and discount_percentage in df_trans
# - merge df_prods and df_trans on product code
# - check on "retail_price" + "size" max in df_prods, may need to adjust for outliers

# %% [markdown]
# ## 03. Data Wrangling + Consistency Checks

# %% [markdown]
# ### Renaming Columns

# %%
df_trans.columns
# Out:
# Index(['full_date', 'year', 'month', 'day_of_month', 'day_of_week', 'time',
#        'Product_code', 'Amount', 'Sale_amount', 'Discount_amount', 'Profit',
#        'Percentage_markup', 'Discount_percentage'],
#       dtype='object')

# %%
# change column names to lower case in df_trans
df_trans.rename(columns = {'Product_code' : 'product_code', 'Amount' : 'units_sold', 'Sale_amount' : 'revenue', 'Discount_amount' : 'discount', 'Profit' : 'profit', 'Percentage_markup' : 'percent_markup', 'Discount_percentage' : 'percent_discount'}, inplace = True)

# %%
df_trans.head()
# Out:
#   full_date  year month  day_of_month day_of_week   time  product_code  \
# 0  1/1/2020  2020   Jan             1   Wednesday  23:00           144
# 1  1/1/2020  2020   Jan             1   Wednesday  23:00           209
# 2  1/1/2020  2020   Jan             1   Wednesday  23:00           213
# 3  1/1/2020  2020   Jan             1   Wednesday  23:00           217
# 4  1/1/2020  2020   Jan             1   Wednesday  23:00           222
#
#    units_sold  revenue  discount  profit  percent_markup  percent_discount
# 0         1.0   280.00       NaN  155.00          124.00               NaN
# 1         2.0   545.73    294.27   75.73           16.11             35.03
# 2         2.0  1265.05     34.95  653.05          106.71              2.69
# 3         1.0   630.00     70.00  220.50           53.85             10.00
# 4         2.0  1104.75    195.25  393.75           55.38             15.02

# %%
df_prods.columns
# Out:
# Index(['Product_code', 'Vendor_code', 'Name', 'Retail_price', 'Base_unit',
#        'Country_of_Origin', 'Size', 'ABV'],
#       dtype='object')

# %%
df_prods.rename(columns = {'Product_code' : 'product_code', 'Vendor_code' : 'vendor', 'Name' : 'name', 'Retail_price' : 'retail_price', 'Base_unit' : 'product_unit', 'Country_of_Origin' : 'vendor_country', 'Size' : 'size', 'ABV' : 'abv'}, inplace = True)

# %%
df_prods.head()
# Out:
#    product_code vendor                                             name  \
# 0          5028    NaN                         1 Symbiotica Apple 0.375
# 1          4846    NaN  1 Symbiotica Hard Kombucha Renegade Aronia 0.33
# 2          1340    NaN                   1000 IBU Imperial IPA Barrel l
# 3          4372    NaN                              18th Street Brewery
# 4          4302    NaN    18th Street Brewery Deal With The Devil 0.473
#
#    retail_price product_unit vendor_country   size  abv
# 0         300.0       Pieces         Russia  0.375  4.5
# 1         200.0       Pieces         Russia  0.330  3.0
# 2         960.0       Liters            NaN  1.000  9.6
# 3           NaN          NaN            USA    NaN  NaN
# 4         630.0       Pieces            USA  0.473  8.5

# %% [markdown]
# ### Notes:
# - is retail price what the bar bought the beer for or the price they sold it to the customer at in df_prods?
# - what's the unit for size in df_prods
# - is revenue, discount, and profit in rubels in df_trans? do I need to convert these or leave as is?

# %% [markdown]
# ### Change Data Type

# %%
# change data type for product_code to be a string
df_prods['product_code'] = df_prods['product_code'].astype('str')

# %%
df_prods['product_code'].dtype
# Out:
# dtype('O')

# %%
df_trans['product_code'] = df_trans['product_code'].astype('str')

# %%
df_trans['product_code'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ### Mixed Types Check

# %%
for col in df_trans.columns.tolist():
  weird = (df_trans[[col]].applymap(type) != df_trans[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_trans[weird]) > 0:
    print (col)

# %%
for col in df_prods.columns.tolist():
  weird = (df_prods[[col]].applymap(type) != df_prods[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_prods[weird]) > 0:
    print (col)
# Out:
# vendor
# product_unit
# vendor_country

# %%
# fix mixed type data in df_prods
df_prods[['vendor', 'product_unit', 'vendor_country']] = df_prods[['vendor', 'product_unit', 'vendor_country']].astype('str')

# %%
for col in df_prods.columns.tolist():
  weird = (df_prods[[col]].applymap(type) != df_prods[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_prods[weird]) > 0:
    print (col)

# %% [markdown]
# ### Note:
# - why did the mix type data not show up when I used df_prods.info()?

# %% [markdown]
# ### Missing Values

# %%
df_trans.isnull().sum()
# Out:
# full_date               0
# year                    0
# month                   0
# day_of_month            0
# day_of_week             0
# time                    0
# product_code            0
# units_sold              0
# revenue                51
# discount            10202
# profit                 14
# percent_markup       1939
# percent_discount    10202
# dtype: int64

# %%
df_trans.shape
# Out:
# (50084, 13)

# %%
df_trans_nan = df_trans[df_trans['revenue'].isnull() == True]

# %%
df_trans_nan.head()
# Out:
#      full_date  year month  day_of_month day_of_week   time product_code  \
# 902  1/14/2020  2020   Jan            14     Tuesday  15:00          340
# 903  1/14/2020  2020   Jan            14     Tuesday  15:00          342
# 914  1/14/2020  2020   Jan            14     Tuesday  15:00          633
# 916  1/14/2020  2020   Jan            14     Tuesday  15:00          637
# 921  1/14/2020  2020   Jan            14     Tuesday  15:00          654
#
#      units_sold  revenue  discount   profit  percent_markup  percent_discount
# 902        2.00      NaN    1200.0  -670.01          -100.0             100.0
# 903        0.25      NaN     220.0  -119.75          -100.0             100.0
# 914        0.50      NaN     480.0  -297.50          -100.0             100.0
# 916        5.00      NaN    3000.0 -1350.00          -100.0             100.0
# 921        2.00      NaN    1600.0  -706.00          -100.0             100.0

# %%
df_trans_nan.tail()
# Out:
#         full_date  year month  day_of_month day_of_week   time product_code  \
# 39499   10/5/2021  2021   Oct             5     Tuesday  19:00         3369
# 40195  10/24/2021  2021   Oct            24      Sunday  19:00         1982
# 42865    1/4/2022  2022   Jan             4     Tuesday   1:00         3803
# 45500    3/7/2022  2022   Mar             7      Monday  18:00         1318
# 45539    3/7/2022  2022   Mar             7      Monday  18:00         3499
#
#        units_sold  revenue  discount  profit  percent_markup  percent_discount
# 39499         1.0      NaN     370.0 -188.70          -100.0             100.0
# 40195         1.0      NaN     450.0  -93.81          -100.0             100.0
# 42865         1.0      NaN     450.0 -230.00          -100.0             100.0
# 45500         1.0      NaN     450.0  -93.81          -100.0             100.0
# 45539         1.0      NaN     460.0 -250.00          -100.0             100.0

# %% [markdown]
# ### Notes:
# - check how many records have a negative profit / make a flag for this for df_trans
# - do not remove any missing data in df_trans

# %%
df_prods.isnull().sum()
# Out:
# product_code        0
# vendor              0
# name                0
# retail_price      436
# product_unit        0
# vendor_country      0
# size              688
# abv               692
# dtype: int64

# %%
df_prods.shape
# Out:
# (5314, 8)

# %%
df_prods_nan = df_prods[df_prods['retail_price'].isnull() == True]

# %%
df_prods_nan.head(30)
# Out:
#     product_code           vendor                           name  \
# 3           4372              nan            18th Street Brewery
# 10          4602              nan                     Lambik Bar
# 11          3488              nan                          Honey
# 13          3041              nan                             2Y
# 45          4728        4 Brewers                       4Brewers
# 58          5111              nan                         Actual
# 59            58            Aegir                          Aegir
# 69            62          AF Brew                        AF Brew
# 103         4083          AF Brew          AF Brew Bounty Killer
# 298         4403          AF Brew                         AF old
# 300         3729              35K      Against The Grain Brewery
# 312         2475              nan                       Alesmith
# 329         2718          Alvinne  Alvinne Cuvee D'Erepigny 0,33
# 374         2066              nan                       Amundsen
# 421          737              nan                         Anchor
# 422         3330              nan                         Anchor
# 433          368  Anderson Valley                Anderson Valley
# 434         3370  Anderson Valley                Anderson Valley
# 453           23              nan                          Anker
# 457          671              nan          Anticipation bottling
# 459          180       Apple Spas                     Apple Spas
# 466          485              nan                        Ardenne
# 468         4416              nan                          Arpus
# 485         2367       Augustiner        Augustiner-Bräu München
# 491         4541              nan                          Axiom
# 498         1208              nan                        Ayinger
# 516         1936          Bakunin                        BAKUNIN
# 517          550          Bakunin                        Bakunin
# 622         1931          Bakunin         BAKUNIN net v nalichii
# 630         1985              nan                        Baladin
#
#      retail_price product_unit vendor_country  size  abv
# 3             NaN          nan            USA   NaN  NaN
# 10            NaN          nan            nan   NaN  NaN
# 11            NaN          nan            nan   NaN  NaN
# 13            NaN          nan            nan   NaN  NaN
# 45            NaN          nan         Russia   NaN  NaN
# 58            NaN          nan            nan   NaN  NaN
# 59            NaN          nan         Norway   NaN  NaN
# 69            NaN          nan         Russia   NaN  NaN
# 103           NaN       Liters         Russia   1.0  6.9
# 298           NaN          nan         Russia   NaN  NaN
# 300           NaN          nan            USA   NaN  NaN
# 312           NaN          nan            USA   NaN  NaN
# 329           NaN       Pieces        Belgium   NaN  NaN
# 374           NaN          nan         Norway   NaN  NaN
# 421           NaN          nan            USA   NaN  NaN
# 422           NaN          nan            USA   NaN  NaN
# 433           NaN          nan            USA   NaN  NaN
# 434           NaN          nan            USA   NaN  NaN
# 453           NaN          nan        Belgium   NaN  NaN
# 457           NaN       Liters        Belgium   NaN  NaN
# 459           NaN          nan         Russia   NaN  NaN
# 466           NaN          nan        Belgium   NaN  NaN
# 468           NaN          nan         Latvia   NaN  NaN
# 485           NaN          nan        Germany   NaN  NaN
# 491           NaN          nan          Czech   NaN  NaN
# 498           NaN          nan        Germany   NaN  NaN
# 516           NaN          nan         Russia   NaN  NaN
# 517           NaN          nan         Russia   NaN  NaN
# 622           NaN          nan         Russia   NaN  NaN
# 630           NaN          nan          Italy   NaN  NaN

# %% [markdown]
# ### Notes:
# - when I changed mixed type data - the NaNs in vendor, product_unit, and vendor_country turned into "nan" as a string
# - it looks like the NaNs in df_prods are products that are not beer - so, I'll make a new dataframe to only include beer

# %%
# create a new dataframe excluding missing values in 'retail_price' in df_prods
df_beer = df_prods[df_prods['retail_price'].isnull() == False]

# %%
df_beer.head(30)
# Out:
#    product_code     vendor                                               name  \
# 0          5028        nan                           1 Symbiotica Apple 0.375
# 1          4846        nan    1 Symbiotica Hard Kombucha Renegade Aronia 0.33
# 2          1340        nan                     1000 IBU Imperial IPA Barrel l
# 4          4302        nan      18th Street Brewery Deal With The Devil 0.473
# 5          4304        nan         18th Street Brewery Pins And Needles 0.473
# 6          4300        nan       18th Street Brewery Rise Of The Angels 0.473
# 7          4775        nan                  18th Street Brewery Rubicon 0.473
# 8          4301        nan            18th Street Brewery Sex and Candy 0.473
# 9          4303        nan              18th Street Brewery Under Crown 0.473
# 12         4738        nan          2nd Shift Brewing Arancia e Ibisco Barrel
# 14          170  3Fonteine         3Fonteinen Doesjel 20/ lambic / 6% / 0.375
# 15         1176  3Fonteine      3Fonteinen Intense Red Oude Kriek / 5% / 0.75
# 16          726  3Fonteine                  3Fonteinen Oude Geuze / 6% / 0.75
# 17         1617  3Fonteine               3Fonteinen Oude Geuze 20/ 5% / 0.375
# 18         4548  3Fonteine        3Fonteinen Oude Geuze 20Assemblage 59 0.375
# 19         1845  3Fonteine  3Fonteinen Oude Geuze 20assemlage 9/Oud Gez 2 ...
# 20         2865  3Fonteine         3Fonteinen Oude Geuze 20Blend No. 55 0.375
# 21         3139  3Fonteine  3Fonteinen Oude Geuze Armand & Gaston Assembla...
# 22         3140  3Fonteine  3Fonteinen Oude Geuze Armand & Gaston Assembla...
# 23         4546  3Fonteine  3Fonteinen Oude Geuze Armand & Gaston Assembla...
# 24         4547  3Fonteine  3Fonteinen Oude Geuze Armand & Gaston Assembla...
# 25         3733  3Fonteine           3Fonteinen Oude Geuze Assamblage 59 0.75
# 26         2242  3Fonteine           3Fonteinen Oude Geuze Assemblage / 0.375
# 27         2243  3Fonteine           3Fonteinen Oude Geuze Assemblage / 0.375
# 28         3141  3Fonteine             3Fonteinen Oude Geuze Assemblage 0.375
# 29         1618  3Fonteine  3Fonteinen Oude Geuze Cuvee Armand & Gaston / ...
# 30         4215  3Fonteine   3Fonteinen Oude Geuze Cuvee Armand & Gaston 1,5L
# 31         2866  3Fonteine  3Fonteinen Oude Geuze Cuvée Armand & Gaston 20...
# 32         2867  3Fonteine  3Fonteinen Oude Geuze Cuvée Armand & Gaston 20...
# 33          171  3Fonteine                3Fonteinen Oude Gueuze / 6% / 0.375
#
#     retail_price product_unit vendor_country   size  abv
# 0          300.0       Pieces         Russia  0.375  4.5
# 1          200.0       Pieces         Russia  0.330  3.0
# 2          960.0       Liters            nan  1.000  9.6
# 4          630.0       Pieces            USA  0.473  8.5
# 5          630.0       Pieces            USA  0.473  8.5
# 6          520.0       Pieces            USA  0.473  7.5
# 7          480.0       Pieces            USA  0.473  7.0
# 8          480.0       Pieces            USA  0.473  7.5
# 9          640.0       Pieces            USA  0.473  8.8
# 12         900.0       Liters            USA  1.000  5.9
# 14         850.0       Pieces        Belgium  0.375  6.0
# 15        3300.0       Pieces        Belgium  0.750  6.0
# 16        1500.0       Pieces        Belgium  0.750  6.0
# 17         950.0       Pieces        Belgium  0.375  5.0
# 18        1100.0       Pieces        Belgium  0.375  6.6
# 19        1600.0       Pieces        Belgium  0.750  5.3
# 20        1100.0       Pieces        Belgium  0.375  5.3
# 21        1550.0       Pieces        Belgium  0.375  6.2
# 22        1550.0       Pieces        Belgium  0.375  6.4
# 23        1550.0       Pieces        Belgium  0.375  6.8
# 24        1550.0       Pieces        Belgium  0.375  6.9
# 25        2000.0       Pieces        Belgium  0.750  6.3
# 26        1000.0       Pieces        Belgium  0.375  5.7
# 27        1050.0       Pieces        Belgium  0.375  5.3
# 28        1100.0       Pieces        Belgium  0.375  6.3
# 29        2500.0       Pieces        Belgium  0.750  5.0
# 30        8000.0       Pieces        Belgium  1.500  6.2
# 31        1600.0       Pieces        Belgium  0.375  5.0
# 32        3200.0       Pieces        Belgium  0.750  5.0
# 33         800.0       Pieces        Belgium  0.375  6.0

# %%
df_beer.shape
# Out:
# (4878, 8)

# %% [markdown]
# ### Duplicate Values

# %%
df_trans_dups = df_trans[df_trans.duplicated()]

# %%
df_trans_dups
# Out:
# Empty DataFrame
# Columns: [full_date, year, month, day_of_month, day_of_week, time, product_code, units_sold, revenue, discount, profit, percent_markup, percent_discount]
# Index: []

# %% [markdown]
# ### Notes: there are no duplicates in df_trans

# %%
df_beer_dups = df_beer[df_beer.duplicated()]

# %%
df_beer_dups
# Out:
# Empty DataFrame
# Columns: [product_code, vendor, name, retail_price, product_unit, vendor_country, size, abv]
# Index: []

# %% [markdown]
# ### Notes: there are no duplicates in df_beer

# %% [markdown]
# ## 04. Merge Data Sets

# %%
df_merge = df_beer.merge(df_trans, on = 'product_code', indicator = True)

# %%
df_merge.head()
# Out:
#   product_code vendor                                             name  \
# 0         5028    nan                         1 Symbiotica Apple 0.375
# 1         5028    nan                         1 Symbiotica Apple 0.375
# 2         5028    nan                         1 Symbiotica Apple 0.375
# 3         4846    nan  1 Symbiotica Hard Kombucha Renegade Aronia 0.33
# 4         4846    nan  1 Symbiotica Hard Kombucha Renegade Aronia 0.33
#
#    retail_price product_unit vendor_country   size  abv  full_date  year  ...  \
# 0         300.0       Pieces         Russia  0.375  4.5   7/3/2022  2022  ...
# 1         300.0       Pieces         Russia  0.375  4.5   7/9/2022  2022  ...
# 2         300.0       Pieces         Russia  0.375  4.5  7/19/2022  2022  ...
# 3         200.0       Pieces         Russia  0.330  3.0  3/20/2022  2022  ...
# 4         200.0       Pieces         Russia  0.330  3.0  3/23/2022  2022  ...
#
#   day_of_month  day_of_week   time units_sold  revenue  discount  profit  \
# 0            3       Sunday   0:00        2.0   420.00    180.00  140.00
# 1            9     Saturday  13:00        4.0   960.00    240.00  400.00
# 2           19      Tuesday  20:00        5.0  1440.00     60.00  740.00
# 3           20       Sunday  17:00        4.0   412.23    277.77   52.23
# 4           23    Wednesday  17:00        2.0   360.00     40.00  180.00
#
#    percent_markup  percent_discount  _merge
# 0           50.00             30.00    both
# 1           71.43             20.00    both
# 2          105.71              4.00    both
# 3           14.51             40.26    both
# 4          100.00             10.00    both
#
# [5 rows x 21 columns]

# %%
# display all columns
pd.options.display.max_columns = None

# %%
df_merge.head(4)
# Out:
#   product_code vendor                                             name  \
# 0         5028    nan                         1 Symbiotica Apple 0.375
# 1         5028    nan                         1 Symbiotica Apple 0.375
# 2         5028    nan                         1 Symbiotica Apple 0.375
# 3         4846    nan  1 Symbiotica Hard Kombucha Renegade Aronia 0.33
#
#    retail_price product_unit vendor_country   size  abv  full_date  year  \
# 0         300.0       Pieces         Russia  0.375  4.5   7/3/2022  2022
# 1         300.0       Pieces         Russia  0.375  4.5   7/9/2022  2022
# 2         300.0       Pieces         Russia  0.375  4.5  7/19/2022  2022
# 3         200.0       Pieces         Russia  0.330  3.0  3/20/2022  2022
#
#   month  day_of_month day_of_week   time  units_sold  revenue  discount  \
# 0   Jul             3      Sunday   0:00         2.0   420.00    180.00
# 1   Jul             9    Saturday  13:00         4.0   960.00    240.00
# 2   Jul            19     Tuesday  20:00         5.0  1440.00     60.00
# 3   Mar            20      Sunday  17:00         4.0   412.23    277.77
#
#    profit  percent_markup  percent_discount _merge
# 0  140.00           50.00             30.00   both
# 1  400.00           71.43             20.00   both
# 2  740.00          105.71              4.00   both
# 3   52.23           14.51             40.26   both

# %%
df_merge.shape
# Out:
# (50081, 21)

# %%
# confirm results
df_merge['_merge'].value_counts()
# Out:
# both          50081
# left_only         0
# right_only        0
# Name: _merge, dtype: int64

# %% [markdown]
# ## 05. Export Data Set

# %%
# export as pickle file
df_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'beer_transactions.pkl'))
